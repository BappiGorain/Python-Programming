# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'

# %%
from pathlib import Path
import imageio.v2 as imageio
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = Path(r'romeo.txt').read_text('utf-8')

mask_image - imageio.imread('mask_heart.png')

wordcloud = WordCloud(colormap='prism',mask=mask_image,background_color='white')

wordcloud = wordcloud.generate(text)

plt.figure(figsize=(8,8))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# !pip install imageio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 9.2 MB/s eta 0:00:000:00:01m eta 0:00:01
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# ...

# %%
# !pip install textatistic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'

# %%
from pathlib import Path
from textatistic import Textatistic
text = Path('romeo.txt').read_text()
readiability = Textatistic(text)
# the statics dictctionary return a dict containing various statics and the readiability score
# %precision 3
readiability.dict()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 2
#       1 from pathlib import Path
# ----> 2 from textatistic import Textatistic
#       3 text = Path('romeo.txt').read_text()
#       4 readiability = Textatistic(text)
#
# File ~/.local/lib/python3.8/site-packages/textatistic/__init__.py:27
#      24 __license__ = 'Apache 2.0'
#      25 __copyright__ = 'Copyright 2015 Erin Hengel'
# ---> 27 from .textatistic import *
#
# File ~/.local/lib/python3.8/site-packages/textatistic/textatistic.py:8
#       6 import os
#       7 from math import sqrt
# ----> 8 from hyphen import Hyphenator
#      11 class EasyWords(object):
#      12     """Object containing Dale-Chall list of easy words."""
#
# ImportError: cannot import name 'Hyphenator' from 'hyphen' (/home/student/.local/lib/python3.8/site-packages/hyphen/__init__.py)

# %%
# !pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
# Out:
# /home/student/.local/lib/python3.8/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.7.1) was trained with spaCy v3.7.2 and may not be 100% compatible with the current version (3.7.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# /bin/bash: python: command not found

# %%
python3 --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 python3 --version
#
# NameError: name 'python3' is not defined

# %%
import sys
# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 9.8 MB/s eta 0:00:000:00:010:00:0101
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 9.7 MB/s eta 0:00:0012.0 MB/s eta 0:00:01
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# ...
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.0
#     Uninstalling spacy-3.7.0:
#       Successfully uninstalled spacy-3.7.0
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import sys
# !{sys.executable} -m pip install spacy
# !{sys.executable} -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
pip install --upgrade spacy==3.7.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 9.5 MB/s eta 0:00:0011.6 MB/s eta 0:00:01
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# ...
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.5
#     Uninstalling spacy-3.7.5:
#       Successfully uninstalled spacy-3.7.5
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
document=nlp("in 1994 Tom Berners_lee founded the"+"world wide web Consortium w3c devotee to"+"developing the web technologies")
document
for entity in document.ents:
    print(f'{entity.text}:{entity.label_}')
# Out:
# 1994:DATE
# Tom Berners_lee:PERSON
# Consortium:ORG

# %%
// Playgrism test

from pathlib import Path
document1 = nlp(Path('romeo.txt').read_text())
document2 = nlp(Path('romeo.txt').read_text())
document1.similarity(document2)
# Out:
# 1.0
