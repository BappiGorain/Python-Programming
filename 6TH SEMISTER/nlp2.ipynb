# %%
from pathlib import Path
from textblob import TextBlob
blob=TextBlob(Path('/home/student/Desktop/Bappi/Python/romeo.txt').read_text())
blob
# Out:
# TextBlob("Romeo and Juliet
# by William Shakespeare
# Edited by Barbara A. Mowat and Paul Werstine
#   with Michael Poston and Rebecca Niles
# Folger Shakespeare Library
# https://shakespeare.folger.edu/shakespeares-works/romeo-and-juliet/
# Created on Jul 31, 2015, from FDT version 0.9.2
#
# Characters in the Play
# ...
# ROMEO
# MONTAGUE, his father
# LADY MONTAGUE, his mother
# BENVOLIO, their kinsman
# ABRAM, a Montague servingman
# BALTHASAR, Romeo's servingman
# JULIET
# CAPULET, her father
# LADY CAPULET, her mother
# NURSE to Juliet
# TYBALT, kinsman to the Capulets
# PETRUCHIO, Tybalt's companion
# Capulet's Cousin
# Servingmen:
#   SAMPSON
#   GREGORY
#   PETER
# Other Servingmen
# ESCALUS, Prince of Verona
# PARIS, the Prince's kinsman and Juliet's suitor
# MERCUTIO, the Prince's kinsman and Romeo's friend
# Paris' Page
# FRIAR LAWRENCE
# FRIAR JOHN
# APOTHECARY
# Three or four Citizens
# Three Musicians
# Three Watchmen
# CHORUS
# ...

# %%
blob.words.count('romeo')
# Out:
# 4

# %%
blob.words.count('a')
# Out:
# 14

# %%
blob.words.count('n')
# Out:
# 0

# %%
blob.words.count('d')
# Out:
# 0

# %%
from textblob import Word
happy=Word('happy')
happy.definitions
# Out:
# ['enjoying or showing or marked by joy or pleasure',
#  'marked by good fortune',
#  'eagerly disposed to act or to be of service',
#  'well expressed and to the point']

# %%
happy.synsets
# Out:
# [Synset('happy.a.01'),
#  Synset('felicitous.s.02'),
#  Synset('glad.s.02'),
#  Synset('happy.s.04')]

# %%
Happy is the original word lamitatzen form
a is the part of speech.
    
a for adjective
v for verb
s for satellite
n for noun
r for adverb



01 is o based index number
many words many form. this is the corresponding meaning in the wordnet DD

# %%
syno = set()
for synset in happy.synsets:
    for lemmas in synset.lemmas():
        syno.add(lemmas.name())


syno
# Out:
# {'felicitous', 'glad', 'happy', 'well-chosen'}

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/student/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stops=stopwords.words('english')
stops
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
blob = TextBlob('Today is the beautiful day.')
[word for word in blob.words if word not in stops]
# Out:
# ['Today', 'beautiful', 'day']

# %%
blob = TextBlob('Text blob is easy to use.')
[word for word in blob.words if word not in stops]
# Out:
# ['Text', 'blob', 'easy', 'use']

# %%
blob = TextBlob('Text blob is easy to use. Tommorow looks bad weather')
blob.ngrams(3)
# Out:
# [WordList(['Text', 'blob', 'is']),
#  WordList(['blob', 'is', 'easy']),
#  WordList(['is', 'easy', 'to']),
#  WordList(['easy', 'to', 'use']),
#  WordList(['to', 'use', 'Tommorow']),
#  WordList(['use', 'Tommorow', 'looks']),
#  WordList(['Tommorow', 'looks', 'bad']),
#  WordList(['looks', 'bad', 'weather'])]

# %%
blob = TextBlob('TextBlob is easy to use')
blob.ngrams(3)
# Out:
# [WordList(['TextBlob', 'is', 'easy']),
#  WordList(['is', 'easy', 'to']),
#  WordList(['easy', 'to', 'use'])]

# %%
from pathlib import Path
from textblob import TextBlob
blob=TextBlob(Path('/home/student/Desktop/Bappi/Python/romeo.txt').read_text())
blob

from nltk.corpus import stopwords
stops=stopwords.words('english')
stops

items=blob.word_counts.items()
items

items = [item for item in items if item[0] not in stops]
items
# Out:
# [('romeo', 4),
#  ('juliet', 4),
#  ('william', 1),
#  ('shakespeare', 2),
#  ('edited', 1),
#  ('barbara', 1),
#  ('mowat', 1),
#  ('paul', 1),
#  ('werstine', 1),
#  ('michael', 1),
#  ('poston', 1),
#  ('rebecca', 1),
#  ('niles', 1),
#  ('folger', 1),
#  ('library', 1),
#  ('https', 1),
#  ('shakespeare.folger.edu/shakespeares-works/romeo-and-juliet', 1),
#  ('created', 1),
#  ('jul', 1),
#  ('31', 1),
#  ('2015', 1),
#  ('fdt', 1),
#  ('version', 1),
#  ('0.9.2', 1),
#  ('characters', 1),
#  ('play', 1),
#  ('montague', 8),
#  ('father', 2),
#  ('lady', 3),
#  ('mother', 2),
#  ('benvolio', 5),
#  ('kinsman', 4),
#  ('abram', 7),
#  ('servingman', 3),
#  ('balthasar', 1),
#  ('capulet', 8),
#  ('nurse', 1),
#  ('tybalt', 6),
#  ('capulets', 2),
#  ('petruchio', 1),
#  ('companion', 1),
#  ('cousin', 1),
#  ('servingmen', 3),
#  ('sampson', 24),
#  ('gregory', 20),
#  ('peter', 1),
#  ('escalus', 1),
#  ('prince', 3),
#  ('verona', 2),
#  ('paris', 2),
#  ('suitor', 1),
# ...
